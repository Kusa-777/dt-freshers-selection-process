# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # performance scorecard

# %% [markdown]
# # week1

# %%
df=pd.DataFrame({'Neha':[8,9,9],'Amit':[8,8,7],'Sachin':[8,8,7]},index=['How happy are you with the Student Unicorns contribution',
'How happy are you with the initiation of the Student Unicorn?',
'How satisfied are you with Student Unicorns ability to identify bottlenecks and come up with solutions?'])
df.plot(kind='barh')
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('performance scorecard week1')
# Out:
# Text(0.5, 1.0, 'performance scorecard week1')

# %% [markdown]
# # week2

# %%
df=pd.read_csv('enter.csv')
df
df=pd.DataFrame(data=df)
df=df.set_index('index')
df
# Out:
#                                                     Neha  Amit  Sachin
# index
# How happy are you with the Student Unicorns con...     9     8       7
# How happy are you with the initiation of the St...     9     8       7
# How satisfied are you with Student Unicorns abi...     5     6       6

# %%
df.plot(kind='barh')
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('performance scorecard week2')
# Out:
# Text(0.5, 1.0, 'performance scorecard week2')

# %% [markdown]
# # week3

# %%
df=pd.read_csv('enter1.csv')
df
df=pd.DataFrame(data=df)
df=df.set_index('index')
df
# Out:
#                                                     Neha  Amit  Sachin
# index
# How happy are you with the Student Unicorns con...     9     8       8
# How happy are you with the initiation of the St...     8     7       7
# How satisfied are you with Student Unicorns abi...     8     6       6

# %%
df.plot(kind='barh')
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('performance scorecard week3')
# Out:
# Text(0.5, 1.0, 'performance scorecard week3')

# %% [markdown]
# # overall 3 weeks based performance

# %%
df=pd.read_csv('final1.csv')
df
df=pd.DataFrame(data=df)
df=df.set_index('index')
df
# Out:
#                                                     Neha  Amit  Sachin
# index
# How happy are you with the Student Unicorns con...   8.6   7.6     7.6
# How happy are you with the initiation of the St...   7.6   7.3     6.6
# How satisfied are you with Student Unicorns abi...   8.3   7.0     7.0

# %%
df.plot(kind='barh')
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('performance scorecard week3')
# Out:
# Text(0.5, 1.0, 'performance scorecard week3')

# %% [markdown]
# # Happiness Scorecard

# %% [markdown]
# # week 1

# %%
df=pd.read_csv('enter2.csv')
df
df=pd.DataFrame(data=df)
df=df.set_index('Parameters')
df
# Out:
#                                                 Neha  Amit  Sachin
# Parameters
# How happy you felt this week?                      6     8       7
# Are you happy with your performance this week?     7    10       7
# Were you satisfied with yourself?                  6     9       7
# How much you enjoyed your work?                    7     9      10
# Were you able to get help that you wanted?         9     9      10
# Were you clear about the tasks given to you?       8    10      10

# %%
df.plot(kind='bar',figsize=(20,5))
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('Happiness scorecard week1')
# Out:
# Text(0.5, 1.0, 'Happiness scorecard week1')

# %% [markdown]
# # week 2

# %%
df=pd.read_csv('enter3.csv')
df
df=pd.DataFrame(data=df)
df=df.set_index('Parameters')
df
# Out:
#                                                 Neha  Amit  Sachin
# Parameters
# How happy you felt this week?                      7     6       9
# Are you happy with your performance this week?     7     7       9
# Were you satisfied with yourself?                  7     7       9
# How much you enjoyed your work?                    7     9       9
# Were you able to get help that you wanted?         7     9      10
# Were you clear about the tasks given to you?       8    10      10

# %%
df.plot(kind='bar',figsize=(20,10))
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('Happiness scorecard week2')
# Out:
# Text(0.5, 1.0, 'Happiness scorecard week2')

# %% [markdown]
# # week 3

# %%
df=pd.read_csv('enter4.csv')
df
df=pd.DataFrame(data=df)
df=df.set_index('Parameters')
df
# Out:
#                                                     Neha  Amit  Sachin
# Parameters
# Were you happy about this week's contributions?        9     9       9
# How happy are you feeling with the efforts you ...     8     9       9
# Were you satisfied with yourself?                      8    10       8
# How much you enjoyed your work?                        8     9      10
# Were you able to get help that you wanted?             8     9       9
# How often were you able to put forth your ideas?      10     8       9

# %%
df.plot(kind='barh',figsize=(10,25))
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('Happiness scorecard week3')
# Out:
# Text(0.5, 1.0, 'Happiness scorecard week3')

# %% [markdown]
# # Progress of Candidates

# %% [markdown]
# # week1

# %%
df=pd.read_csv('enter8.csv')
df
df=pd.DataFrame(data=df)
df=df.set_index('Parameters')
df
# Out:
#                                                     Neha  Amit  Sachin
# Parameters
# Q1 How would you grade yourself in terms of the...    10     8       6
# Q1 On a scale of 1-10 how much is the above par...    10     8       8
# Q2 How much effort do you put in "learning and ...     9     7       4
# Q2 On a scale of 1-10 compared to the other par...     9     8       8
# Q3 Beyond your core domain what are the efforts...     9     8       7
# Q3 On a scale of 1-10 compared to the other par...     9     8       7
# Q4 What are the efforts have you given to impro...     9     8       7
# Q4 On a scale of 1-10 compared to the other par...     9     8       6
# Q5 How much efforts have you given in order to ...     9     8       6
# Q5 On a scale of 1-10 compared to the other par...     9     8       6

# %%
df.plot(kind='barh',figsize=(10,15))
plt.xlabel('parameters')
plt.ylabel('values')
plt.title('Progress of candidates')
# Out:
# Text(0.5, 1.0, 'Progress of candidates')

# %% [markdown]
# # week 2

# %%
df=pd.read_csv('enter7.csv')
df
# Out:
#                                           Parameters  \
# 0  Q1 According to you What does X represents in ...
# 1  [Q2 According to you What does A B and C repre...
# 2  [Q3 According to you What does M N and O repre...
# 3  [Q4 According to you What does P Q and R repre...
# 4  Can you elaborate on why did you chose  those ...
# 5             Score Recived by candidate in the test
#
#                                                 Neha  \
# 0  The Problem statement which the company is pur...
# 1                               Deliverables to meet
# 2  The Key Results of the work The Key Performanc...
# 3                     The Key Performance Indicators
# 4   "Many times company faces such challenges whe...
# 5                                              2 / 4
#
#                                                 Amit  \
# 0                           An Objective of the team
# 1                               Deliverables to meet
# 2  Deliverables to meet The numbers to chase in o...
# 3                     The Key Performance Indicators
# 4   1. The purpose of X is nothing but knowing ou...
# 5                                              3 / 4
#
#                                               Sachin
# 0                           An Objective of the team
# 1                              Deliverables to meet.
# 2  The numbers to chase in order to complete the ...
# 3                    The Key Performance Indicators.
# 4   1. X is the goal or purpose the team need to ...
# 5                                              3 / 4

# %% [markdown]
# based on above table im answering for each question.
# From looking at the answers and the scores, it can be seen that Neha has scored 2/4. From a quick look, it can be inferred seems she has answered questions 1 and 3 wrongly, as her answers to questions 2 and 4 match up with the others, and they got points for those.
#
# Similarly, it can be ascertained that as Amit and Sachin have both received 3/4, and since the only answer they have given differently is of question 3, that is probably the answer they got wrong.
#
# Since all the candidates had problems with question 3, it makes sense to have a look at the question and their answers. And taking a look at their reasoning would also help understand their thinking. Other than these two features, I don't think the answers to the other questions need much analysis; we already know the correct answers for them.

# %% [raw]
# Q3. According to you, What does M, N and O represent in the story? (You can select more than one option)
#
# Neha's Response
#
# Answer:
#
# The Key Results of the work, The Key Performance Indicators, The numbers to chase in order to complete the deliverable, Deliverables to meet.
#
# Reasoning:
#
# Many times company faces such challenges where innovation is only thing required, Apart company objectives, mission deliverables become so important to create some new milestone, For that we need The Key Results of the work The Key Performance Indicators The numbers to chase in order to complete the deliverable Deliverables to meet in aligned form, And in that case The Key Performance Indicators helps a lot as a base tool.
#
# Amit's response
#
# Answer:
# Deliverables to meet, The numbers to chase in order to complete the deliverable, The Key Results of the work
#
# Reasoning:
#
# The purpose of X is nothing but knowing our end goal i.e, the objective of team. 2. A, B & C are nothing but the deliverables to meet since the team had mutually decided to work on them. 3. M, N & O are our tracking metrics which help team to be on their toes to reach their targets 4. P , Q & R are key metrics which helps team to visualize what to work on and what can be kept on a bucket list.
# Sachin's response
#
# Answer:
#
# The numbers to chase in order to complete the deliverable, The Key Performance Indicators
#
# Reasoning:
#
# X is the goal or purpose the team need to achieved that is given by the higher authority in the company. 2.X goal is broken down into 3parts that is A B C .these are the 3 tasks that needs to be achieved by the team . 3.M N O are the exact numbers and their descriptions on how the tasks need to be done or achieved, these are the KPI s and numbers that the team need to achieve. 4.P Q R are the key performance indicators of the team ,they need to be achieved in order for a team to show its progress and it will allow them to track their performance

# %% [markdown]
# "The numbers to chase in order to complete the deliverable"
# "Deliverables to meet"
# Interestingly, none of the candidates have selected just these two options. I do think selecting these two options should be the correct answer, as the excerpt mentions numbers and deliverables.

# %%
df=pd.read_csv('title3.csv')
df
# Out:
#                                           Parameters  \
# 0  On an average What percentage of the work you ...
# 1  What percentage of the work you did were unpla...
# 2  Roughly how much productive do you feel what p...
# 3  Can you elaborate on why did you chose  those ...
# 4  What did you utilize from the following to com...
# 5  What among the following according to you will...
# 6  Why would it help you to grow? How would you u...
# 7  Do you think that you can do better / more con...
#
#                                                 Neha  \
# 0                                         around 75%
# 1                                               half
# 2                                               >85%
# 3  "So as we're reaching to the final part of our...
# 4  Your prior academic/ technical skills Help of ...
# 5  Academic/ technical skills Learning from Works...
# 6  All these holds wide impact to help us grow as...
# 7  I can do double times contribution than this week
#
#                                                 Amit  \
# 0                                               100%
# 1                                               <25%
# 2                                               >85%
# 3  Cause it was mutually decided in presence of o...
# 4  Your prior academic/ technical skills Help of ...
# 5  Learning from Workshops / Courses Learning fro...
# 6  Cross all the options gives broader perspectiv...
# 7  I can do 1.25 times more contribution than thi...
#
#                                               Sachin
# 0                                               half
# 1                                               half
# 2                                               >85%
# 3  "This week was quite productive .I took initia...
# 4  Your prior academic/ technical skills Help of ...
# 5  Academic/ technical skills Learning from Works...
# 6  Everything mentioned above would help me grow ...
# 7     I can do 1.5 times contribution than this week

# %% [markdown]
# Q1 On an average, What percentage of the work you did, was pre-planned?
# ans:for neha 100%,for amit half and for sachine half
# Q2 What percentage of the work you did were unplanned, to give a freedom of exploration and initiate new ideas?
# ans:half for neha, <25 for amit and fo sachin half
# Q3 Roughly how much productive do you feel, what percentage of planned work were you able to complete
# for every person >85%
# Q4 Can you elaborate on why did you chose those options to answer the above questions?
# Q5 What did you utilize from the following to complete the work at your company? (You can select more than one option)
# ans:we can select any one of them.
# Q6 What among the following, according to you will help you as an individual to grow ahead in your future? (You can select more than one option)
# ans:we can select any one of mentioned in the above table
# Q7 Why would it help you to grow? How would you utilize them to grow at the fullest potential?
#  ans:All of them have selected similar responses in the previous question
# Q8 Do you think that you can do better / more contributions than what you mentioned above? How many times better can you perform?
# for this question answer is mentioned in above table

# %% [markdown]
# for question 4 answered by each person give below
# Neha:
#
# "So, as we're reaching to the final part of our internship we finalized our final agenda "Digital Media Marketing" is one of the main KPI's on our bucket list -Regarding this, we as a team decide what we plan to do : Content Front 1) One time it could be creating a strategy report. 2) Another time it could be creating post content & have a discussion around it. 3) Some other time it could be designing analytics for the posts we've created and sharing our thoughts on that analysis stating where we can improve better so on and so forth ... so as our agenda is clear we will decide what can be planned this week as a part of KPI/OKR's. Coming back to the point there's a Product front as well. So every week I will be receiving the upcoming week's plan - Features to be worked on kind of Plan of Action for internal team members (Dreamworks.co). I need to know how it works and come up with Feature documentation where Amit started to join the club recently and created the same old pattern which I started. 1)Personas 2)User Story 3)User Flow. Upon our Lead's suggestion we added one more aspect 4) Use case scenarios. So as you can see this is the combination of our plan+ Seniors delegation to work on !"
#
# Amit:
#
# "Cause it was mutually decided in presence of our lead and then we were assigned to the tasks. That is why I chose that option. There is nothing else to mention"
# Sachin:
#
# "This week was quite productive. I took initiatives to take up work like working on the new feature list. Extened my research on my previous competitive analysis with new prespective and websites. Worked on more than 20+ feature list wrote product initiatives documents for them . Helped the team with brainstorming ideas for LinkedIn post as well, the week was fun and productive. I feel I worked efficiently this week and hope to continue to do so in upcoming week."

# %% [markdown]
# for question 6 answered by person is given below
# Q6 Answer: Academic/ technical skills, Learning from Workshops / Courses, Learning from Cross-functional Holistic Sessions, Help received currently from the team, Your creative initiatives and innovative solutions, Help of mentor / senior organization
#
# "All these holds wide impact to help us grow as an individual also as an team player who can help others to get in same boat from where the development becomes a key factor across the eco-system."
#
# Amit:
#
# Q6 Answer: Learning from Workshops / Courses, Learning from Cross-functional Holistic Sessions, Your creative initiatives and innovative solutions, Help of mentor / senior organization
#
# "Cross all the options gives broader perspectives to nurture and innovate"
#
# Sachin:
#
# Q6 Answer: Academic/ technical skills, Learning from Workshops / Courses, Learning from Cross-functional Holistic Sessions, Help received currently from the team, Your creative initiatives and innovative solutions, Help of mentor / senior organization
#
# "Everything mentioned above would help me grow, learn new things and will allow me to contribute to my organisation"

# %% [markdown]
# # questions i  would you ask the company, employees to understand the data better? What additional data would you require to draw better inferences out of the data?

# %% [markdown]
# from my side i have few doubts regarding above three projects
# 1)sir you gave data is informated but from progress of candidate,for week 2,3 what you are expecting from myside?
# 2)by giving information of week 2 and 3 from progress of candidate table, what requires from me for client?
# 3)for the table progress of progress of candidate for week 2 and 3 everyone thinks that we should visualize that table.but improving requirements of data using nlp we can visualize.
# 4)in happiness of scorecard,in week 1 neha is not happy compared to amit and sachin, but next 2 weeks she is improved, but what reason behind that? it may be hilarious question but considering is best.
# And better include average values of three weeks of happiness scorecard to visualize easier.
# 5)in comparing with performance scorecard and happiness scorecard ,progress of candidate information is not much informated to visualize.better improving information in last weeks.
